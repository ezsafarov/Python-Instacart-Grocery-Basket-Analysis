# %%
# import the “products.csv” data set from your “Original Data” 
#folder as df_prods


import pandas as pd
import numpy as np
import os

# Define the updated base directory path
path = r'/Users/emilsafarov/Library/CloudStorage/OneDrive-Personal/CF/A4_Python/Instacart Basket Analysis/02 Data/Original data'

# Correctly join the base path with the relative path to the CSV file
df_prods = pd.read_csv(os.path.join(path, 'products.csv'))


# Display the first five rows of the df_prods
df_prods.head(35)
# Out:
#     product_id                                       product_name  aisle_id  \
# 0            1                         Chocolate Sandwich Cookies        61
# 1            2                                   All-Seasons Salt       104
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 3            4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4            5                          Green Chile Anytime Sauce         5
# 5            6                                       Dry Nose Oil        11
# 6            7                     Pure Coconut Water With Orange        98
# 7            8                  Cut Russet Potatoes Steam N' Mash       116
# 8            9                  Light Strawberry Blueberry Yogurt       120
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# ...

# %%
# importing “orders_wrangled.csv” data set from your “Prepared Data” 
#folder as df_ords

# Define the updated base directory path
path = r'/Users/emilsafarov/Library/CloudStorage/OneDrive-Personal/CF/A4_Python/Instacart Basket Analysis/02 Data/Prepared data'

# Correctly join the base path with the relative path to the CSV file
df_ords = pd.read_csv(os.path.join(path, 'orders_wrangled.csv'))

# renaming column name from order_dow to 
df_ords.rename(columns={'order_dow': 'order_day_of_week'}, inplace = True)

# Display the first five rows of the df_ords
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_day_of_week  \
# 0           0   2539329        1             1                  2
# 1           1   2398795        1             2                  3
# 2           2    473747        1             3                  3
# 3           3   2254736        1             4                  4
# 4           4    431534        1             5                  4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
# conducting descriptive analysis for df_ords

df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        order_day_of_week  order_hour_of_day  days_since_prior_order
# count       3.421083e+06       3.421083e+06            3.214874e+06
# mean        2.776219e+00       1.345202e+01            1.111484e+01
# std         2.046829e+00       4.226088e+00            9.206737e+00
# min         0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
# crete a df
df_test = pd.DataFrame()
df_test['mix'] = ['a', 'b', 1, True]
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
df_test['mix'] = df_test['mix'].astype('str')
df_test.head()
# Out:
#     mix
# 0     a
# 1     b
# 2     1
# 3  True

# %%
df_test['mix'].dtype
# Out:
# dtype('O')

# %%
df_prods.isnull().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %% [markdown]
# df_nan =  df_prods[df_prods['product_name'].isnull() == 1]
# df_nan

# %%
df_nan = df_prods[df_prods['product_name'].isnull() == 1] 
df_nan
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 33             34          NaN       121             14    12.2
# 68             69          NaN        26              7    11.8
# 115           116          NaN        93              3    10.8
# 261           262          NaN       110             13    12.1
# 525           525          NaN       109             11     1.2
# 1511         1511          NaN        84             16    14.3
# 1780         1780          NaN       126             11    12.3
# 2240         2240          NaN        52              1    14.2
# 2586         2586          NaN       104             13    12.4
# 3159         3159          NaN       126             11    13.1
# 3230         3230          NaN       120             16    14.4
# 3736         3736          NaN        41              8    14.8
# 4283         4283          NaN        77              7    14.4
# 4790         4790          NaN        91             16    14.5
# ...

# %%
df_prods.dropna(subset = ['product_name'], inplace = True)

# %%
df_nan = df_prods[df_prods['product_name'].isnull() == 1] 
df_nan
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id, prices]
# Index: []

# %%
df_prods.isnull().sum()
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# prices           0
# dtype: int64

# %%
df_prods.shape
# Out:
# (49677, 5)

# %%
df_dups = df_prods_celan[df_prods_clean.duplicated()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df_dups = df_prods_celan[df_prods_clean.duplicated()]
#
# NameError: name 'df_prods_celan' is not defined

# %%
df_dups

# %%
df_prods_celan.drop_duplicates()

# %%
df_prods_clean_no_dupes = df_prods_celan.drop_duplicates()

# %%
df_prods_clean_no_dupes.shape

# %%
# saving the file back

# Creating path back - modified path
path = r'/Users/emilsafarov/Library/CloudStorage/OneDrive-Personal/CF/A4_Python/Instacart Basket Analysis/02 Data/Prepared data'

# exporting “orders_wrangled.csv” in your “Prepared Data” folder
df_prods_clean_no_dupes.to_csv(os.path.join(path, 'products_checked.csv'))

# %%
# Step 2 - Working with df_ords

# %%
# import the “orders.csv” data set from your “Original Data” 
#folder as df_ords


import pandas as pd
import numpy as np
import os

# Define base directory path
path = r'/Users/emilsafarov/Library/CloudStorage/OneDrive-Personal/CF/A4_Python/Instacart Basket Analysis/02 Data/Prepared data'

# Join the base path with the relative path to the CSV file - I got wrangled file from Prepared data folder
df_ords = pd.read_csv(os.path.join(path, 'orders_wrangled.csv'))

# renaming column name from order_dow to order_day_of_week
df_ords.rename(columns={'order_dow': 'order_day_of_week'}, inplace = True)

# Display the first five rows of the df_ords
df_ords.tail()

# %%
# Step 2 runing the df.describe() function on your df_ords dataframe
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05  1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04  1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04  5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05  1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05  2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        order_day_of_week  order_hour_of_day  days_since_prior_order
# count       3.421083e+06       3.421083e+06            3.214874e+06
# mean        2.776219e+00       1.345202e+01            1.111484e+01
# std         2.046829e+00       4.226088e+00            9.206737e+00
# min         0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# Based on descriptive analysis all data points are within the norms,
# nothing odd is observed

# %%
# Step 3cand 4 Check for mixed-type data in your df_ords dataframe - with implementation of AI

# Checking unique data types within each column
mixed_types = df_ords.applymap(type).nunique()
print(mixed_types[mixed_types > 1])  # Shows columns with more than one data type

# 2 Identify columns with non-numeric data if they should be numeric
non_numeric_in_numeric = df_ords.select_dtypes(exclude=[np.number]).columns
print("Potential mixed types in numeric columns:", non_numeric_in_numeric)

# %%
# df appears to have consistent data types in all columns, 
#with no mixed types

# %%
# Step 5 and 6 Run a check for missing values in your df_ords dataframe

df_ords.isnull().sum()

# %%
# defining the count of all columns and rows
df_ords.shape

# %%
df_nan = df_ords[df_ords['days_since_prior_order'].isnull() == 1] 
df_nan

# %% [markdown]
# Based on the analysis in total 206209 rows are missed in the 'days_since_prior_order' column, which makes more than 6%

# %%
# Define the part and whole values
part = 206209
whole = 3421083

# Calculate the percentage
percentage = (part/whole) * 100

# Display the result
print(f"The percentage is: {percentage}%")

# %% [markdown]
# After a deeper analysis, I created a bar chart in Tableau to visualize the distribution of "days_since_prior_order". The results show an unusual pattern, with most values concentrated at exactly 30 days, which likely indicates that any gap longer than 30 days has been capped at this maximum value. This accounts for approximately 60% of the available data, which may reduce the accuracy of our analysis. Additionally, this distribution does not follow a normal (Gaussian) distribution (.jpeg file is attached).
#
# Since the 30-day cap skews the data and "days_since_prior_order" represents only around 6% of the dataset, it does not appear to be a crucial variable for our analysis. Therefore, I suggest either leaving the column as it is or considering removing it entirely, as its inclusion may introduce inaccuracies and obscure our findings' clarity.
#
# ![Image of dd](02%20Data/Prepared%20data/dd.jpeg)

# %%
# Step 7 and 8 Run a check for duplicate values in your df_ords data.

# %%
# defining duplicates
df_dups = df_ords[df_ords.duplicated()]
df_dups

# %%
# checking the count of duplicates
duplicate_count = df_ords.duplicated().sum()
print(f"Total duplicates: {duplicate_count}")

# %% [markdown]
# Based on analysis there are no duplicates in the df, which is a sign of high accuracy

# %%
# importing the files into Prepared data folder

# %%
# path back 
path = r'/Users/emilsafarov/Library/CloudStorage/OneDrive-Personal/CF/A4_Python/Instacart Basket Analysis/02 Data/Prepared data'

# exporting “orders” as orders_wrangled_and_cleaned_data in “Prepared Data” folder
df_ords.to_csv(os.path.join(path, 'orders_wrangled_and_cleaned_data.csv'))

# exporting “products” as producs_wrangled_and_cleaned_data in “Prepared Data” folder
df_prods.to_csv(os.path.join(path, 'prods_wrangled_and_cleaned_data.csv'))
